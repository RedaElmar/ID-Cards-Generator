# %% [markdown]
# <img src="../Res/header.png" />

# %% [markdown]
# # ID Card Generator Project P001 CODE ESI

# %% [markdown]
# ### Imports

# %%
import pandas as pd 
import pdfkit
from datetime import datetime, timedelta
import code128
import random

# %% [markdown]
# ### Functions

# %%
#generate costum html file using the arguments
def HTMLgen(code,first_name,last_name,function,date_of_birth,picture,expiration_date):
    html= r"""<!doctype html><meta charset="utf-8"><link rel="stylesheet" href="../RES/card.css"><body><div class="face face-front" ><img src="../RES/front.png"></div><div id="infoi"><img src="@picture" height="89.5" width="83" />
        <div style="margin-left: 1.3cm;margin-top: -0.6cm;">
            <br>
            <div style="font-size: 0.7em;margin-top: 5%;font-family: sans-serif;color: aliceblue;text-transform: uppercase;"><b>@fname</b> @lname</div><br>
        <div style="font-size: 0.7em;margin-top: -0.4cm;font-family: sans-serif;color: aliceblue;text-t ransform: capitalize;">@function</div>
        </div>
    </div>
    <div id="info">
        <br><div style="font-size: 0.7em;margin-top: 0.6%;font-family: sans-serif;text-transform: uppercase;">@code</div>
        <br><div style="font-size: 0.7em;margin-top: -0.6%;font-family: sans-serif;text-transform: capitalize;">@date_of_birth</div>
        <br><div style="font-size: 0.7em;margin-top: -0.6%;font-family: sans-serif;text-transform: capitalize;">@expiration_date</div>
    </div>
    <div id="BARCODE"><img src="../RES/bar.PNG"  height="20" width="120"/></div>

</body>"""
    html = html.replace("@picture",picture)
    html = html.replace("@code",str(code))
    html = html.replace("@fname",first_name)
    html = html.replace("@lname",last_name)
    html = html.replace("@function",function)
    html = html.replace("@date_of_birth",date_of_birth)
    html = html.replace("@expiration_date",expiration_date)
    f= open("index.html","w")
    f.write(html)
    f.close()
    return 
#generate a file bar.png contains barcode of the 10 digits code  
def BARgen(code):
    code128.image(code).save("../RES/bar.png")
    return
#generate costum pdf file using the existing html file // code argument is only to name the file generated
def PDFgen(code):
    config = pdfkit.configuration(wkhtmltopdf='C:\\Program Files\\wkhtmltopdf\\bin\\wkhtmltopdf.exe')
    options = {'dpi': 365,'margin-top': '0in','margin-bottom': '0in','margin-right': '0in','margin-left': '0in','page-size': 'A8',"orientation": "Landscape",'disable-smart-shrinking': ''}
    pdfkit.from_file('index.html', str(code)+".pdf",configuration=config , options = options)
    return       
#complete with random digits an integer x until it contains 10 digits
def complete(x):
    x=str(x)
    while len(x)<10:
            x+=str(random.randint(0,9))
    return int(x)

# %% [markdown]
# ### Import Dataset

# %%
data=pd.read_excel("../RES/exo_dataset_P001.xlsx")

# %% [markdown]
# ### Show Sample

# %%
data.head(40)
# Out:
#           code first_name     last_name                       function  \
# 0   5591927432      Prent  Hickenbottom                  Senior Editor
# 1   5071682362       Jard         Stein            Geological Engineer
# 2   6295398980      Levon          Noen          Research Assistant IV
# 3   3718164078      Nonah       Scoggin               Junior Executive
# 4   2261412840    Jameson    Hugueville                        Teacher
# 5   7226393395    Lynnett      Hambrick           Software Engineer II
# 28      2/8/1993       11/4/2019
# 29     15/4/1998       27/3/2019
# 30    15/12/1992       17/3/2019
# 31     7/12/1992        2/3/2019
# 32     14/8/1993       23/3/2019
# 33      7/1/1992       29/3/2019
# 34    26/11/1999       26/1/2019
# 35      6/5/1993       22/3/2019
# 36     26/2/1993       13/4/2019
# 37     10/4/1998       18/2/2019
# 38     15/9/1995       13/4/2019
# 39      7/4/1995        4/3/2019
#
#                                               picture
# 0   https://robohash.org/quidemsaepequi.png?size=3...
# 1   https://robohash.org/teneturautsunt.png?size=3...
# 2   https://robohash.org/quaeetsed.png?size=300x30...
# 3   https://robohash.org/debitisinciduntdolore.png...
# 4   https://robohash.org/facilisrerumad.png?size=3...
# 5   https://robohash.org/eosculpaquam.png?size=300...
# 6   https://robohash.org/cumofficiarepudiandae.png...
# 7   https://robohash.org/etdoloribusreiciendis.png...
# 8   https://robohash.org/suntliberoveritatis.png?s...
# 9   https://robohash.org/suscipithicest.png?size=3...
# 10  https://robohash.org/etetconsequatur.png?size=...
# 11  https://robohash.org/reprehenderitdebitisnobis...
# 12  https://robohash.org/seddictaab.png?size=300x3...
# 13  https://robohash.org/undeidveritatis.png?size=...
# 14  https://robohash.org/doloresillumvitae.png?siz...
# 15  https://robohash.org/autiustoreiciendis.png?si...
# 16  https://robohash.org/utinmolestias.png?size=30...
# 17  https://robohash.org/quodvoluptatesdebitis.png...
# 18  https://robohash.org/porroetnobis.png?size=300...
# 19  https://robohash.org/consequatursitcupiditate....
# 20  https://robohash.org/inciduntomnisqui.png?size...
# 21  https://robohash.org/quoadaut.png?size=300x300...
# 22  https://robohash.org/nemosimiliquevelit.png?si...
# 23  https://robohash.org/voluptatemvelexcepturi.pn...
# 24  https://robohash.org/doloriureeum.png?size=300...
# 25  https://robohash.org/inciduntcumexercitationem...
# 26  https://robohash.org/nesciuntsitdebitis.png?si...
# 27  https://robohash.org/voluptatemdolorofficiis.p...
# 28  https://robohash.org/quiaestnon.png?size=300x3...
# 29  https://robohash.org/essererumvoluptatem.png?s...
# 30  https://robohash.org/etrerumrepudiandae.png?si...
# 31  https://robohash.org/rerumsedvel.png?size=300x...
# 32  https://robohash.org/oditenimlaborum.png?size=...
# 33  https://robohash.org/sintpariaturut.png?size=3...
# 34  https://robohash.org/utasperiorescum.png?size=...
# 35  https://robohash.org/quibusdamnontotam.png?siz...
# 36  https://robohash.org/praesentiumquiafacere.png...
# 37  https://robohash.org/nostrumexcepturirem.png?s...
# 38  https://robohash.org/suntsedsimilique.png?size...
# 39  https://robohash.org/rematquevoluptatum.png?si...

# %% [markdown]
# As you can see some of the code entries are only 9 digits or less, so we will add some random degits to them.

# %%
data['code'] = data['code'].apply(lambda x: complete(x))

# %%
data.dtypes
# Out:
# code                int64
# first_name         object
# last_name          object
# function           object
# date_of_birth      object
# submission_date    object
# picture            object
# dtype: object

# %% [markdown]
# ### convert to datetime elements

# %%
data['submission_date']=pd.to_datetime(data['submission_date'])
data['date_of_birth'] = pd.to_datetime(data['date_of_birth'])

# %%
data.dtypes
# Out:
# code                        int64
# first_name                 object
# last_name                  object
# function                   object
# date_of_birth      datetime64[ns]
# submission_date    datetime64[ns]
# picture                    object
# dtype: object

# %%
data.head(5)
# Out:
#          code first_name     last_name               function date_of_birth  \
# 0  5591927432      Prent  Hickenbottom          Senior Editor    1993-04-03
# 1  5071682362       Jard         Stein    Geological Engineer    1992-07-15
# 2  6295398980      Levon          Noen  Research Assistant IV    1999-12-10
# 3  3718164078      Nonah       Scoggin       Junior Executive    2000-09-07
# 4  2261412840    Jameson    Hugueville                Teacher    1991-05-12
#
#   submission_date                                            picture
# 0      2019-01-22  https://robohash.org/quidemsaepequi.png?size=3...
# 1      2019-10-04  https://robohash.org/teneturautsunt.png?size=3...
# 2      2019-03-27  https://robohash.org/quaeetsed.png?size=300x30...
# 3      2019-01-21  https://robohash.org/debitisinciduntdolore.png...
# 4      2019-01-02  https://robohash.org/facilisrerumad.png?size=3...

# %% [markdown]
# ### add expiration date column (submission date + 15 days)

# %%
data["expiration_date"] = data["submission_date"] + timedelta(days=15)

# %% [markdown]
# ### Controlling date form DD-MM-YYYY

# %%
data['date_of_birth']=data['date_of_birth'].dt.strftime('%d-%m-%Y')
data['submission_date']=data['submission_date'].dt.strftime('%d-%m-%Y')
data['expiration_date']=data['expiration_date'].dt.strftime('%d-%m-%Y')

# %%
data.head(5)
# Out:
#          code first_name     last_name               function date_of_birth  \
# 0  5591927432      Prent  Hickenbottom          Senior Editor    03-04-1993
# 1  5071682362       Jard         Stein    Geological Engineer    15-07-1992
# 2  6295398980      Levon          Noen  Research Assistant IV    10-12-1999
# 3  3718164078      Nonah       Scoggin       Junior Executive    07-09-2000
# 4  2261412840    Jameson    Hugueville                Teacher    12-05-1991
#
#   submission_date                                            picture  \
# 0      22-01-2019  https://robohash.org/quidemsaepequi.png?size=3...
# 1      04-10-2019  https://robohash.org/teneturautsunt.png?size=3...
# 2      27-03-2019  https://robohash.org/quaeetsed.png?size=300x30...
# 3      21-01-2019  https://robohash.org/debitisinciduntdolore.png...
# 4      02-01-2019  https://robohash.org/facilisrerumad.png?size=3...
#
#   expiration_date
# 0      06-02-2019
# 1      19-10-2019
# 2      11-04-2019
# 3      05-02-2019
# 4      17-01-2019

# %% [markdown]
# ### Generating Costumized Pdf files from the dataset

# %%
for index, row in data.head(n=5).iterrows()    :
    code=row[0]
    fname = row[1]
    lname = row[2]
    func  = row[3]
    dob   = row[4]
    ed    = row[5]
    pic   = row[6]
    BARgen(code)
    HTMLgen(code,fname,lname,func,dob,pic,ed)
    PDFgen(code)
# Out:
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done

# %% [markdown]
# #### **generated 5 pdf files with thier corresponding enteries**

# %% [markdown]
# <p float="left">
# <img align="left" src="../Res/PDFS.png" width="250"/><img src="../Res/GIF.gif" width="450" />
# </p>

# %% [markdown]
# ### done
